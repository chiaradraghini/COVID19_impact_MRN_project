# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib.colors import ListedColormap
from datetime import datetime
import time

# %%
#getting the stored dataframe with median calculations over the week days of January
# %store -r df0_jan
# %store -r df1_jan
# %store -r df2_jan
# %store -r df3_jan 
# %store -r df4_jan
# %store -r df5_jan
# %store -r df6_jan

# %%
#re-organizing rows and columns for each day 
df0_jan_pivot = df0_jan.pivot(index='ECELL_ID', columns='Hours', values='Median DL_VOL')
df1_jan_pivot = df1_jan.pivot(index='ECELL_ID', columns='Hours', values='Median DL_VOL')
df2_jan_pivot = df2_jan.pivot(index='ECELL_ID', columns='Hours', values='Median DL_VOL')
df3_jan_pivot = df3_jan.pivot(index='ECELL_ID', columns='Hours', values='Median DL_VOL')
df4_jan_pivot = df4_jan.pivot(index='ECELL_ID', columns='Hours', values='Median DL_VOL')
df5_jan_pivot = df5_jan.pivot(index='ECELL_ID', columns='Hours', values='Median DL_VOL')
df6_jan_pivot = df6_jan.pivot(index='ECELL_ID', columns='Hours', values='Median DL_VOL')
df6_jan_pivot
# Out:
# Hours                                     Sunday at 0  Sunday at 1  \
# ECELL_ID
# 00199ffaae391a819e512627bdaff10347c4fd13   19875644.0   22345660.0
# 019cfa281650073eb1ed07c2202dbc289d0423c5   12887368.0    9733344.0
# 01e15165b5683c9f4922e7ffdc82471e479e7779    6899480.0    9258736.0
# 0424fc3a83b05aa9108aabdd8cbb087814a34bd1   12017924.0    9510356.0
# 046b22f684551e03511a06d4c2489c4ce47e9446     999312.0     905492.0
# ...                                               ...          ...
# fbb375f9f0a4f004475be02539cd98ad87edefac   22296956.0    7636280.0
# fc151d76149c8066a9d19e0279dcf9f5fbfbb2e0    7205280.0    4122080.0
# fde3676655dbd432364e7468ba06a2daaf385e4c   38545300.0   35255892.0
# fe64706273bed80a3fa4a13093f4d8d825ab2228    7985496.0    4119932.0
# ffbb644800b874c89350a70d5acdc8d0fe051755    9954688.0    3047180.0
#
# Hours                                     Sunday at 10  Sunday at 11  \
# ECELL_ID
# 00199ffaae391a819e512627bdaff10347c4fd13     6897040.0     9068944.0
# ...

# %%
result = pd.concat([df0_jan_pivot, df1_jan_pivot, df2_jan_pivot, df3_jan_pivot, df4_jan_pivot, df5_jan_pivot, df6_jan_pivot], axis=1)
result
# Out:
# Hours                                     Monday at 0  Monday at 1  \
# ECELL_ID
# 00199ffaae391a819e512627bdaff10347c4fd13   33069296.0   22457216.0
# 019cfa281650073eb1ed07c2202dbc289d0423c5   19330088.0    8285528.0
# 01e15165b5683c9f4922e7ffdc82471e479e7779   10074440.0    4853896.0
# 0424fc3a83b05aa9108aabdd8cbb087814a34bd1   15496852.0   18425572.0
# 046b22f684551e03511a06d4c2489c4ce47e9446     627112.0     311420.0
# ...                                               ...          ...
# fbb375f9f0a4f004475be02539cd98ad87edefac    7522292.0    4018588.0
# fc151d76149c8066a9d19e0279dcf9f5fbfbb2e0    3258596.0    1298648.0
# fde3676655dbd432364e7468ba06a2daaf385e4c   38738648.0   36594952.0
# fe64706273bed80a3fa4a13093f4d8d825ab2228    8337952.0    6019552.0
# ffbb644800b874c89350a70d5acdc8d0fe051755    8004672.0   12455744.0
#
# Hours                                     Monday at 10  Monday at 11  \
# ECELL_ID
# 00199ffaae391a819e512627bdaff10347c4fd13    15670440.0    12483012.0
# ...

# %%
result.to_csv("/Users/chiaradraghini/Documents/mrn_project/data/k-means/dataset/weekdays.csv")
